# %%
import exploring_inflation

# %%
exploring_inflation.compare_regions(['Countrywide','Midwest','Northeast'],2022,2023,type='Derived')

# %%
exploring_inflation.compare_regions(['Countrywide','Midwest'],2018,2023,type='Normal')

# %%
exploring_inflation.compare_regions(['Countrywide','Midwest'],2018,2023,type='Ratio')

# %%
exploring_inflation.compare_regions(['Countrywide','Midwest','Northeast','South','West'],2018,2022,type='Ratio')
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File c:\Users\jhqui\AppData\Local\Programs\Python\Python310\lib\site-packages\urllib3\connection.py:174, in HTTPConnection._new_conn(self)
#     173 try:
# --> 174     conn = connection.create_connection(
#     175         (self._dns_host, self.port), self.timeout, **extra_kw
#     176     )
#     178 except SocketTimeout:
#
# File c:\Users\jhqui\AppData\Local\Programs\Python\Python310\lib\site-packages\urllib3\util\connection.py:95, in create_connection(address, timeout, source_address, socket_options)
#      94 if err is not None:
# ---> 95     raise err
#      97 raise socket.error("getaddrinfo returns an empty list")
#
# File c:\Users\jhqui\AppData\Local\Programs\Python\Python310\lib\site-packages\urllib3\util\connection.py:85, in create_connection(address, timeout, source_address, socket_options)
# ...
